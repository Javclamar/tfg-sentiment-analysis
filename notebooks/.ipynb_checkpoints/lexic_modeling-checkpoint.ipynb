# %%
import polars as pl
import nltk
from nltk.sentiment import SentimentIntensityAnalyzer
import concurrent.futures
from tqdm import tqdm
import time
import os
import math

# %%
LEXICONS_AVAILABLE = {
    "vader_score": calcular_vader,
    "afinn_score": calcular_afinn
}

def calcular_vader(texts):
    sia = SentimentIntensityAnalyzer()
    return [sia.polarity_scores(str(t))['compound'] for t in texts]

def calcular_afinn(texts):
    afinn = Afinn()
    scores = []
    alpha = 15
    for t in texts:
        raw = afinn.score(str(t))
        norm = raw / math.sqrt((raw**2) + alpha) if raw != 0 else 0.0
        scores.append(norm)
    return scores

def process_chunk_(args):
    """
    args es una tupla: (lista_textos, lista_modelos_a_usar)
    Esto es necesario porque executor.map solo pasa un argumento.
    """
    texts, active_models = args
    
    results = {}
    
    # Ejecutamos solo los modelos solicitados
    for col_name in active_models:
        if col_name in MODELS_AVAILABLE:
            func = MODELS_AVAILABLE[col_name]
            results[col_name] = func(texts)
            
    return results

# %%
csv_reviews = '../data/csv/yelp_academic_dataset_review.csv'
csv_reviews_output_scores = '../results/vader/yelp_academic_dataset_review_scored.csv'
batch_size = 200000
total_rows = 6_990_280

def analyze_sentiment(input_csv, output_csv, models_to_run=['vader_score', 'afinn_score']):
    
    num_cores = os.cpu_count()
    
    try:
        temp_df = pl.read_csv(input_csv, n_rows=1, ignore_errors=True)
        final_columns = temp_df.columns + models_to_run 
        
        with open(output_csv, 'w') as f:
            f.write(",".join([f'"{c}"' for c in final_columns]) + "\n")
    except Exception as e:
        print(f"Error: {e}")
        return

    reader = pl.read_csv_batched(input_csv, batch_size=batch_size, ignore_errors=True)
    
    start_time = time.time()
    
    with concurrent.futures.ProcessPoolExecutor(max_workers=num_cores) as executor:
        with tqdm(total = total_rows, unit="reviews", desc="Procesando") as pbar:
            
            while True:
                batches = reader.next_batches(1)
                if not batches: break
                
                df_batch = batches[0]
                texts = df_batch["text"].to_list()
                current_rows = len(texts)

                chunk_size = math.ceil(len(texts) / num_cores)
                text_chunks = [texts[i:i + chunk_size] for i in range(0, len(texts), chunk_size)]
                
                worker_args = [(chunk, models_to_run) for chunk in text_chunks]
                
                results_generator = executor.map(process_chunk, worker_args)
                
                batch_results = {model: [] for model in models_to_run}
                
                for res_dict in results_generator:
                    for model in models_to_run:
                        batch_results[model].extend(res_dict[model])
                
                df_scored = df_batch
                for model in models_to_run:
                    df_scored = df_scored.with_columns(def analyze_sentiment_modular(input_csv, output_csv, models_to_run=['vader_score', 'afinn_score']):
    
    print(f"--- Iniciando Análisis ---")
    print(f"Modelos activados: {models_to_run}")
    
    num_cores = os.cpu_count()
    batch_size = 200000
    
    # 1. Preparar Cabeceras
    # Leemos la cabecera original y añadimos SOLO las columnas de los modelos elegidos
    try:
        temp_df = pl.read_csv(input_csv, n_rows=1, ignore_errors=True)
        # Columnas originales + Modelos nuevos
        final_columns = temp_df.columns + models_to_run 
        
        with open(output_csv, 'w') as f:
            # Escribimos cabecera manual para asegurar orden
            f.write(",".join([f'"{c}"' for c in final_columns]) + "\n")
    except Exception as e:
        print(f"Error: {e}")
        return

    # 2. Configurar Reader y Executor
    reader = pl.read_csv_batched(input_csv, batch_size=batch_size, ignore_errors=True)
    
    start_time = time.time()
    
    with concurrent.futures.ProcessPoolExecutor(max_workers=num_cores) as executor:
        # Nota: tqdm necesita un total estimado, pon tu número de filas aquí
        with tqdm(unit="reviews", desc="Procesando") as pbar:
            
            while True:
                batches = reader.next_batches(1)
                if not batches: break
                
                df_batch = batches[0]
                texts = df_batch["text"].to_list()
                current_rows = len(texts)

                # A. Dividir en sub-chunks para los núcleos
                chunk_size = math.ceil(len(texts) / num_cores)
                text_chunks = [texts[i:i + chunk_size] for i in range(0, len(texts), chunk_size)]
                
                # B. Preparar argumentos para el worker (Texto + Config)
                # Pasamos la configuración 'models_to_run' a cada worker
                worker_args = [(chunk, models_to_run) for chunk in text_chunks]
                
                # C. Ejecutar en paralelo
                results_generator = executor.map(process_chunk_dynamic, worker_args)
                
                # D. Recolectar resultados ordenados
                # Inicializamos listas vacías para cada modelo activo
                batch_results = {model: [] for model in models_to_run}
                
                for res_dict in results_generator:
                    for model in models_to_run:
                        batch_results[model].extend(res_dict[model])
                
                # E. Crear DataFrame con las nuevas columnas
                # Empezamos con el batch original
                df_scored = df_batch
                for model in models_to_run:
                    df_scored = df_scored.with_columns(
                        pl.Series(name=model, values=batch_results[model], dtype=pl.Float64)
                    )
                
                # F. Escribir (Append) - IMPORTANTE: Mantener orden de columnas
                # .select garantiza que escribimos en el mismo orden que la cabecera
                df_scored.select(final_columns).write_csv(
                    file=open(output_csv, "a"),
                    include_header=False,
                    quote_style="always" # Más seguro para texto libre
                )
                
                pbar.update(current_rows)

    print(f"Tiempo total: {(time.time() - start_time) / 60:.2f} min")

# --- USO ---

# Opción A: Correr todo a la vez (Máxima eficiencia I/O)
analyze_sentiment_modular(
    sv_reviews, 
    '../results/yelp_full_scored.csv', 
    models_to_run=['vader_score', 'afinn_score']
)def analyze_sentiment_modular(input_csv, output_csv, models_to_run=['vader_score', 'afinn_score']):
    
    print(f"--- Iniciando Análisis ---")
    print(f"Modelos activados: {models_to_run}")
    
    num_cores = os.cpu_count()
    batch_size = 200000
    
    # 1. Preparar Cabeceras
    # Leemos la cabecera original y añadimos SOLO las columnas de los modelos elegidos
    try:
        temp_df = pl.read_csv(input_csv, n_rows=1, ignore_errors=True)
        # Columnas originales + Modelos nuevos
        final_columns = temp_df.columns + models_to_run 
        
        with open(output_csv, 'w') as f:
            # Escribimos cabecera manual para asegurar orden
            f.write(",".join([f'"{c}"' for c in final_columns]) + "\n")
    except Exception as e:
        print(f"Error: {e}")
        return

    # 2. Configurar Reader y Executor
    reader = pl.read_csv_batched(input_csv, batch_size=batch_size, ignore_errors=True)
    
    start_time = time.time()
    
    with concurrent.futures.ProcessPoolExecutor(max_workers=num_cores) as executor:
        # Nota: tqdm necesita un total estimado, pon tu número de filas aquí
        with tqdm(unit="reviews", desc="Procesando") as pbar:
            
            while True:
                batches = reader.next_batches(1)
                if not batches: break
                
                df_batch = batches[0]
                texts = df_batch["text"].to_list()
                current_rows = len(texts)

                # A. Dividir en sub-chunks para los núcleos
                chunk_size = math.ceil(len(texts) / num_cores)
                text_chunks = [texts[i:i + chunk_size] for i in range(0, len(texts), chunk_size)]
                
                # B. Preparar argumentos para el worker (Texto + Config)
                # Pasamos la configuración 'models_to_run' a cada worker
                worker_args = [(chunk, models_to_run) for chunk in text_chunks]
                
                # C. Ejecutar en paralelo
                results_generator = executor.map(process_chunk_dynamic, worker_args)
                
                # D. Recolectar resultados ordenados
                # Inicializamos listas vacías para cada modelo activo
                batch_results = {model: [] for model in models_to_run}
                
                for res_dict in results_generator:
                    for model in models_to_run:
                        batch_results[model].extend(res_dict[model])
                
                # E. Crear DataFrame con las nuevas columnas
                # Empezamos con el batch original
                df_scored = df_batch
                for model in models_to_run:
                    df_scored = df_scored.with_columns(
                        pl.Series(name=model, values=batch_results[model], dtype=pl.Float64)
                    )
                
                # F. Escribir (Append) - IMPORTANTE: Mantener orden de columnas
                # .select garantiza que escribimos en el mismo orden que la cabecera
                df_scored.select(final_columns).write_csv(
                    file=open(output_csv, "a"),
                    include_header=False,
                    quote_style="always" # Más seguro para texto libre
                )
                
                pbar.update(current_rows)

    print(f"Tiempo total: {(time.time() - start_time) / 60:.2f} min")

# --- USO ---

# Opción A: Correr todo a la vez (Máxima eficiencia I/O)
analyze_sentiment_modular(
    sv_reviews, 
    '../results/yelp_full_scored.csv', 
    models_to_run=['vader_score', 'afinn_score']
)def analyze_sentiment_modular(input_csv, output_csv, models_to_run=['vader_score', 'afinn_score']):
    
    print(f"--- Iniciando Análisis ---")
    print(f"Modelos activados: {models_to_run}")
    
    num_cores = os.cpu_count()
    batch_size = 200000
    
    # 1. Preparar Cabeceras
    # Leemos la cabecera original y añadimos SOLO las columnas de los modelos elegidos
    try:
        temp_df = pl.read_csv(input_csv, n_rows=1, ignore_errors=True)
        # Columnas originales + Modelos nuevos
        final_columns = temp_df.columns + models_to_run 
        
        with open(output_csv, 'w') as f:
            # Escribimos cabecera manual para asegurar orden
            f.write(",".join([f'"{c}"' for c in final_columns]) + "\n")
    except Exception as e:
        print(f"Error: {e}")
        return

    # 2. Configurar Reader y Executor
    reader = pl.read_csv_batched(input_csv, batch_size=batch_size, ignore_errors=True)
    
    start_time = time.time()
    
    with concurrent.futures.ProcessPoolExecutor(max_workers=num_cores) as executor:
        # Nota: tqdm necesita un total estimado, pon tu número de filas aquí
        with tqdm(unit="reviews", desc="Procesando") as pbar:
            
            while True:
                batches = reader.next_batches(1)
                if not batches: break
                
                df_batch = batches[0]
                texts = df_batch["text"].to_list()
                current_rows = len(texts)

                # A. Dividir en sub-chunks para los núcleos
                chunk_size = math.ceil(len(texts) / num_cores)
                text_chunks = [texts[i:i + chunk_size] for i in range(0, len(texts), chunk_size)]
                
                # B. Preparar argumentos para el worker (Texto + Config)
                # Pasamos la configuración 'models_to_run' a cada worker
                worker_args = [(chunk, models_to_run) for chunk in text_chunks]
                
                # C. Ejecutar en paralelo
                results_generator = executor.map(process_chunk_dynamic, worker_args)
                
                # D. Recolectar resultados ordenados
                # Inicializamos listas vacías para cada modelo activo
                batch_results = {model: [] for model in models_to_run}
                
                for res_dict in results_generator:
                    for model in models_to_run:
                        batch_results[model].extend(res_dict[model])
                
                # E. Crear DataFrame con las nuevas columnas
                # Empezamos con el batch original
                df_scored = df_batch
                for model in models_to_run:
                    df_scored = df_scored.with_columns(
                        pl.Series(name=model, values=batch_results[model], dtype=pl.Float64)
                    )
                
                # F. Escribir (Append) - IMPORTANTE: Mantener orden de columnas
                # .select garantiza que escribimos en el mismo orden que la cabecera
                df_scored.select(final_columns).write_csv(
                    file=open(output_csv, "a"),
                    include_header=False,
                    quote_style="always" # Más seguro para texto libre
                )
                
                pbar.update(current_rows)

    print(f"Tiempo total: {(time.time() - start_time) / 60:.2f} min")

# --- USO ---

# Opción A: Correr todo a la vez (Máxima eficiencia I/O)
analyze_sentiment_modular(
    sv_reviews, 
    '../results/yelp_full_scored.csv', 
    models_to_run=['vader_score', 'afinn_score']
)
                        pl.Series(name=model, values=batch_results[model], dtype=pl.Float64)
                    )
                
                df_scored.select(final_columns).write_csv(
                    file=open(output_csv, "a"),
                    include_header=False,
                    quote_style="always"
                )
                
                pbar.update(current_rows)

    print(f"Tiempo total: {(time.time() - start_time) / 60:.2f} min")

analyze_sentiment(csv_reviews, csv_reviews_output_scores, models_to_run=['vader_score', 'afinn_score'])
# Out:
# Procesando: 0reviews [07:19, ?reviews/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 64
#      60                 pbar.update(current_rows)
#      62     print(f"Tiempo total: {(time.time() - start_time) / 60:.2f} min")
# ---> 64 analyze_sentiment(csv_reviews, csv_reviews_output_scores, models_to_run=['vader_score', 'afinn_score'])
#
# Cell In[9], line 44, in analyze_sentiment(input_csv, output_csv, models_to_run)
#      40 results_generator = executor.map(process_chunk, worker_args)
#      42 batch_results = {model: [] for model in models_to_run}
# ---> 44 for res_dict in results_generator:
#      45     for model in models_to_run:
#      46         batch_results[model].extend(res_dict[model])
#
# File /usr/lib/python3.12/concurrent/futures/process.py:642, in _chain_from_iterable_of_lists(iterable)
#     636 def _chain_from_iterable_of_lists(iterable):
# ...

# %%
csv_reviews_output_scores = '../results/vader/yelp_academic_dataset_review_scored.csv'

print(pl.scan_csv(csv_reviews_output_scores, ignore_errors=True).head(5).collect())
# Out:
# shape: (5, 8)
# ┌─────────────┬────────────┬────────────┬───────┬────────────┬────────────┬───────────┬────────────┐
# │ review_id   ┆ user_id    ┆ business_i ┆ stars ┆ text       ┆ date       ┆ num_chars ┆ vader_scor │
# │ ---         ┆ ---        ┆ d          ┆ ---   ┆ ---        ┆ ---        ┆ ---       ┆ e          │
# │ str         ┆ str        ┆ ---        ┆ i64   ┆ str        ┆ str        ┆ i64       ┆ ---        │
# │             ┆            ┆ str        ┆       ┆            ┆            ┆           ┆ f64        │
# ╞═════════════╪════════════╪════════════╪═══════╪════════════╪════════════╪═══════════╪════════════╡
# │ KU_O5udG6zp ┆ mh_-eMZ6K5 ┆ XQfwVwDr-v ┆ 3     ┆ If you     ┆ 2018-07-07 ┆ 513       ┆ 0.8597     │
# │ xOg-VcAEodg ┆ RLWhZyISBh ┆ 0ZS3_CbbE5 ┆       ┆ decide to  ┆ 22:09:11   ┆           ┆            │
# │             ┆ wA         ┆ Xw         ┆       ┆ eat here,  ┆            ┆           ┆            │
# ...
