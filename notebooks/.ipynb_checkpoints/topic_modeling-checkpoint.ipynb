# %%
import polars as pl
import numpy as np
import time
from sklearn.decomposition import LatentDirichletAllocation
from sklearn.feature_extraction.text import CountVectorizer

# %%
csv_reviews = '../data/csv/yelp_academic_dataset_review.csv'

def lda_model_training(input_csv):
    
    sample_df = (
        pl.scan_csv(input_csv)
        .select('text')
        .collect()
        .sample(n=300000, seed=42) 
    )
    
    sample_df = sample_df.with_columns(
        pl.col('text').str.replace_all(r'[^a-zA-Z\s]', '').str.to_lowercase().alias('clean_text')
    )
    
    vectorizer = CountVectorizer(stop_words='english', max_features=25000, max_df=0.85, min_df=10)
    vectorizer.fit(sample_df['clean_text'].to_list())
    
    del sample_df
    
    lda = LatentDirichletAllocation(
        n_components=15,           
        learning_method='online',  
        n_jobs=-1,                 
        batch_size=50000,          
        random_state=42
    )
    
    start_time = time.time()
    reader = pl.read_csv_batched(input_csv, batch_size=50000)
    
    batch_count = 0
    
    while True:
        batches = reader.next_batches(1)
        if not batches:
            break
        
        chunk = batches[0]
        
        chunk = chunk.with_columns(
            pl.col('text').str.replace_all(r'[^a-zA-Z\s]', '').str.to_lowercase().alias('clean_text')
        )
        
        X_chunk = vectorizer.transform(chunk['clean_text'].to_list())
        
        lda.partial_fit(X_chunk)
        
        batch_count += 1
        if batch_count % 10 == 0:
            elapsed_mins = (time.time() - start_time) / 60
            rows_processed = batch_count * 50000
            print(f"Processed {rows_processed:,} rows in {elapsed_mins:.2f} minutes...")
    
    print(f"Training completed successfully in {(time.time() - start_time) / 60:.2f} minutes.")

lda_model_training(csv_reviews)
# Out:
# Processed 500,000 rows in 1.04 minutes...
# Processed 1,000,000 rows in 1.94 minutes...
# Processed 1,500,000 rows in 2.75 minutes...
# Processed 2,000,000 rows in 3.51 minutes...
# Processed 2,500,000 rows in 4.29 minutes...
# Processed 3,000,000 rows in 5.07 minutes...
# Processed 3,500,000 rows in 5.85 minutes...
# Processed 4,000,000 rows in 6.60 minutes...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 57
#      53             print(f"Processed {rows_processed:,} rows in {elapsed_mins:.2f} minutes...")
#      55     print(f"Training completed successfully in {(time.time() - start_time) / 60:.2f} minutes.")
# ---> 57 lda_model_training(csv_reviews)
#
# Cell In[8], line 47, in lda_model_training(input_csv)
#      41 chunk = chunk.with_columns(
#      42     pl.col('text').str.replace_all(r'[^a-zA-Z\s]', '').str.to_lowercase().alias('clean_text')
# ...

# %%
csv_reviews = '../data/csv/yelp_academic_dataset_review.csv'
csv_reviews_output_topics = '../results/yelp_academic_dataset_review_topics.csv'

def lda_topic_modeling(input_csv, output_csv):
    start_time = time.time()

    reader = pl.read_csv_batched(input_csv, batch_size=50000)

    batch_count = 0
    
    while True:
        batches = reader.next_batches(1)
        if not batches:
            break # End of file
        
        chunk = batches[0]
        
        # 3. Clean and vectorize (same exact logic as training)
        cleaned_texts = chunk['text'].str.replace_all(r'[^a-zA-Z\s]', '').str.to_lowercase().to_list()
        X_chunk = vectorizer.transform(cleaned_texts)
        
        # 4. INFERENCE: Get the probability distribution across all 15 topics
        # lda.transform() returns a matrix of shape (n_samples, n_components)
        topic_distributions = lda.transform(X_chunk)
        
        # 5. Extract the top topic and its confidence score using NumPy
        dominant_topics = np.argmax(topic_distributions, axis=1)
        topic_probs = np.max(topic_distributions, axis=1)
        
        # 6. Package the results into a new Polars DataFrame
        chunk = chunk.with_columns([
                pl.Series("dominant_topic", dominant_topics),
                pl.Series("topic_probability", topic_probs)
            ])
        
        mode = 'wb' if batch_count == 0 else 'ab'
        with open(output_csv, mode) as f:
            chunk.write_csv(f, include_header=(batch_count == 0))

        batch_count += 1
        if batch_count % 10 == 0:
            elapsed_mins = (time.time() - start_time) / 60
            print(f"Processed and saved {batch_count * 50000:,} rows in {elapsed_mins:.2f} minutes...")
    
    print(f"Saved to {output_csv} in {(time.time() - start_time) / 60:.2f} minutes.")
